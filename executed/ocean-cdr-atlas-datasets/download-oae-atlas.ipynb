# %% [markdown]
# # OAE Atlas Dataset
#
# This notebook downloads a curated subset of the Ocean Carbon Dioxide Removal (OAE) Atlas dataset to a local cache using the S3 access helpers in `cdr_atlas.py`. It also provides quick visual checks and documentation of what is being downloaded.
#
# Dataset hosted on Source Cooperative: https://source.coop/cworthy/oae-efficiency-atlas
#
# ## Dataset summary
#
# - The dataset contains results from thousands of CESM ocean alkalinity enhancement simulations.
# - Files are organized by polygon (region), injection month, and simulation year/month.
# - Each experiment includes perturbation variables and counterfactual variables (suffix `_ALT_CO2`).
# - Polygon masks and efficiency maps are provided as NetCDF files.
#
# Use this notebook to prefetch data in batches to avoid repeated downloads during analysis.

# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path

import numpy as np
import xarray as xr
import yaml

import cdr_atlas
# Out:
# /global/homes/m/mattlong/.conda/envs/atlas-calcs/lib/python3.13/site-packages/pop_tools/__init__.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution

# %% [markdown]
# ## Configuration
#
# Choose a polygon ID, injection month, and a set of model years to download. The files follow:
#
# ```
# experiments/{polygon_id}/{injection_month}/alk-forcing.{polygon_id}-{injection_year}-{injection_month}.pop.h.{year}-{month}.nc
# ```
#
# `polygon_id` ranges from 000–690 and `injection_month` is typically 01/04/07/10 for the published experiments. Use `n_test` to limit the number of files pulled.
#
# Model year 0347 corresponds to the calendar year 1999, thus we need a `model_year_offset` to align the model calendar with the true calendar year.

# %% [markdown]
# :::{note}
# `n_test = None` to download the full temporal dataset range of the datasets at the specified
# `polygon_id`, `injection_year`, `injection_month`.
#
# If all these parameters are `None`, all available data will be downloaded.
# :::

# %%
batch_size = 50

 # set any to None to download all available
polygon_id = 1
injection_year = 1999
injection_month = 1

# n_test limits the number of files downloaded
n_test = 3

dask_cluster_kwargs = {}

# %%
# Parameters
polygon_id = None
injection_year = 1999
injection_month = 1
n_test = None
dask_cluster_kwargs = {
    "account": "m4632",
    "queue_name": "premium",
    "n_nodes": 1,
    "n_tasks_per_node": 128,
    "wallclock": "06:00:00",
    "scheduler_file": None,
}

# %% [markdown]
# ## Step 1: Identify files to download
#
# We first enumerate all expected files for this polygon/time window. This avoids repeated S3 listings during computation.

# %%
atlas_data = cdr_atlas.DATASET_REGISTRY["oae-efficiency-map_atlas-v0"]
atlas_data.df
# Out:
#                                                                                                 s3_path  \
# injection_year polygon_id injection_month year month
# 1999           0          1               347  1      s3://us-west-2.opendata.source.coop/cworthy/oa...
#                                                2      s3://us-west-2.opendata.source.coop/cworthy/oa...
#                                                3      s3://us-west-2.opendata.source.coop/cworthy/oa...
#                                                4      s3://us-west-2.opendata.source.coop/cworthy/oa...
#                                                5      s3://us-west-2.opendata.source.coop/cworthy/oa...
# ...                                                                                                 ...
#                689        10              362  5      s3://us-west-2.opendata.source.coop/cworthy/oa...
#                                                6      s3://us-west-2.opendata.source.coop/cworthy/oa...
#                                                7      s3://us-west-2.opendata.source.coop/cworthy/oa...
#                                                8      s3://us-west-2.opendata.source.coop/cworthy/oa...
#                                                9      s3://us-west-2.opendata.source.coop/cworthy/oa...
#
#                                                                                              cache_path
# injection_year polygon_id injection_month year month
# 1999           0          1               347  1      /pscratch/sd/m/mattlong/atlas_cache/experiment...
#                                                2      /pscratch/sd/m/mattlong/atlas_cache/experiment...
#                                                3      /pscratch/sd/m/mattlong/atlas_cache/experiment...
#                                                4      /pscratch/sd/m/mattlong/atlas_cache/experiment...
#                                                5      /pscratch/sd/m/mattlong/atlas_cache/experiment...
# ...                                                                                                 ...
#                689        10              362  5      /pscratch/sd/m/mattlong/atlas_cache/experiment...
#                                                6      /pscratch/sd/m/mattlong/atlas_cache/experiment...
#                                                7      /pscratch/sd/m/mattlong/atlas_cache/experiment...
#                                                8      /pscratch/sd/m/mattlong/atlas_cache/experiment...
#                                                9      /pscratch/sd/m/mattlong/atlas_cache/experiment...
#
# [496800 rows x 2 columns]

# %%
manifest = atlas_data.query(polygon_id=polygon_id, injection_year=injection_year, injection_month=injection_month, n_test=n_test)
manifest
# Out:
# [{'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0347-01.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0347-01.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0347-02.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0347-02.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0347-03.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0347-03.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0347-04.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0347-04.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0347-05.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0347-05.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0347-06.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0347-06.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0347-07.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0347-07.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0347-08.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0347-08.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0347-09.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0347-09.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0347-10.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0347-10.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0347-11.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0347-11.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0347-12.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0347-12.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0348-01.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0348-01.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0348-02.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0348-02.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0348-03.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0348-03.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0348-04.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0348-04.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0348-05.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0348-05.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0348-06.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0348-06.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0348-07.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0348-07.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0348-08.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0348-08.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0348-09.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0348-09.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0348-10.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0348-10.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0348-11.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0348-11.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0348-12.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0348-12.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0349-01.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0349-01.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0349-02.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0349-02.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0349-03.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0349-03.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0349-04.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0349-04.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0349-05.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0349-05.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0349-06.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0349-06.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0349-07.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0349-07.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0349-08.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0349-08.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0349-09.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0349-09.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0349-10.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0349-10.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0349-11.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0349-11.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0349-12.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0349-12.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0350-01.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0350-01.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0350-02.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0350-02.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0350-03.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0350-03.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0350-04.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0350-04.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0350-05.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0350-05.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0350-06.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0350-06.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0350-07.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0350-07.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0350-08.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0350-08.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0350-09.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0350-09.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0350-10.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0350-10.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0350-11.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0350-11.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0350-12.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0350-12.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0351-01.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0351-01.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0351-02.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0351-02.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0351-03.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0351-03.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0351-04.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0351-04.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0351-05.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0351-05.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0351-06.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0351-06.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0351-07.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0351-07.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0351-08.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0351-08.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0351-09.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0351-09.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0351-10.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0351-10.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0351-11.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0351-11.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0351-12.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0351-12.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0352-01.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0352-01.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0352-02.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0352-02.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0352-03.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0352-03.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0352-04.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0352-04.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0352-05.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0352-05.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0352-06.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0352-06.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0352-07.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0352-07.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0352-08.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0352-08.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0352-09.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0352-09.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0352-10.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0352-10.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0352-11.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0352-11.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0352-12.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0352-12.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0353-01.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0353-01.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0353-02.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0353-02.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0353-03.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0353-03.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0353-04.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0353-04.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0353-05.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0353-05.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0353-06.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0353-06.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0353-07.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0353-07.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0353-08.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0353-08.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0353-09.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0353-09.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0353-10.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0353-10.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0353-11.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0353-11.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0353-12.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0353-12.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0354-01.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0354-01.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0354-02.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0354-02.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0354-03.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0354-03.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0354-04.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0354-04.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0354-05.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0354-05.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0354-06.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0354-06.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0354-07.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0354-07.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0354-08.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0354-08.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0354-09.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0354-09.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0354-10.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0354-10.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0354-11.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0354-11.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0354-12.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0354-12.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0355-01.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0355-01.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0355-02.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0355-02.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0355-03.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0355-03.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0355-04.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0355-04.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0355-05.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0355-05.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0355-06.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0355-06.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0355-07.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0355-07.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0355-08.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0355-08.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0355-09.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0355-09.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0355-10.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0355-10.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0355-11.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0355-11.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0355-12.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0355-12.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0356-01.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0356-01.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0356-02.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0356-02.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0356-03.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0356-03.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0356-04.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0356-04.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0356-05.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0356-05.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0356-06.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0356-06.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0356-07.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0356-07.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0356-08.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0356-08.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0356-09.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0356-09.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0356-10.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0356-10.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0356-11.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0356-11.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0356-12.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0356-12.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0357-01.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0357-01.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0357-02.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0357-02.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0357-03.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0357-03.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0357-04.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0357-04.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0357-05.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0357-05.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0357-06.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0357-06.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0357-07.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0357-07.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0357-08.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0357-08.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0357-09.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0357-09.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0357-10.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0357-10.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0357-11.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0357-11.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0357-12.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0357-12.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0358-01.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0358-01.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0358-02.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0358-02.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0358-03.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0358-03.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0358-04.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0358-04.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0358-05.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0358-05.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0358-06.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0358-06.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0358-07.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0358-07.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0358-08.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0358-08.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0358-09.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0358-09.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0358-10.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0358-10.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0358-11.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0358-11.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0358-12.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0358-12.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0359-01.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0359-01.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0359-02.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0359-02.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0359-03.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0359-03.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0359-04.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0359-04.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0359-05.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0359-05.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0359-06.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0359-06.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0359-07.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0359-07.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0359-08.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0359-08.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0359-09.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0359-09.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0359-10.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0359-10.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0359-11.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0359-11.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0359-12.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0359-12.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0360-01.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0360-01.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0360-02.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0360-02.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0360-03.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0360-03.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0360-04.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0360-04.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0360-05.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0360-05.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0360-06.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0360-06.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0360-07.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0360-07.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0360-08.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0360-08.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0360-09.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0360-09.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0360-10.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0360-10.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0360-11.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0360-11.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0360-12.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0360-12.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0361-01.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0361-01.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0361-02.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0361-02.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0361-03.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0361-03.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0361-04.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0361-04.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0361-05.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0361-05.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0361-06.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0361-06.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0361-07.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0361-07.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0361-08.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0361-08.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0361-09.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0361-09.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0361-10.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0361-10.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0361-11.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0361-11.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/000/01/alk-forcing.000-1999-01.pop.h.0361-12.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/000/01/alk-forcing.000-1999-01.pop.h.0361-12.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/001/01/alk-forcing.001-1999-01.pop.h.0347-01.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/001/01/alk-forcing.001-1999-01.pop.h.0347-01.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/001/01/alk-forcing.001-1999-01.pop.h.0347-02.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/001/01/alk-forcing.001-1999-01.pop.h.0347-02.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/001/01/alk-forcing.001-1999-01.pop.h.0347-03.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/001/01/alk-forcing.001-1999-01.pop.h.0347-03.nc'},
# ...
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0350-04.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0350-04.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0350-05.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0350-05.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0350-06.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0350-06.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0350-07.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0350-07.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0350-08.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0350-08.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0350-09.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0350-09.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0350-10.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0350-10.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0350-11.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0350-11.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0350-12.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0350-12.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0351-01.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0351-01.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0351-02.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0351-02.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0351-03.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0351-03.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0351-04.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0351-04.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0351-05.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0351-05.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0351-06.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0351-06.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0351-07.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0351-07.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0351-08.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0351-08.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0351-09.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0351-09.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0351-10.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0351-10.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0351-11.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0351-11.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0351-12.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0351-12.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0352-01.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0352-01.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0352-02.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0352-02.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0352-03.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0352-03.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0352-04.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0352-04.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0352-05.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0352-05.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0352-06.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0352-06.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0352-07.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0352-07.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0352-08.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0352-08.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0352-09.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0352-09.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0352-10.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0352-10.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0352-11.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0352-11.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0352-12.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0352-12.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0353-01.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0353-01.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0353-02.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0353-02.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0353-03.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0353-03.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0353-04.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0353-04.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0353-05.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0353-05.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0353-06.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0353-06.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0353-07.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0353-07.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0353-08.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0353-08.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0353-09.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0353-09.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0353-10.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0353-10.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0353-11.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0353-11.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0353-12.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0353-12.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0354-01.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0354-01.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0354-02.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0354-02.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0354-03.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0354-03.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0354-04.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0354-04.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0354-05.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0354-05.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0354-06.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0354-06.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0354-07.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0354-07.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0354-08.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0354-08.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0354-09.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0354-09.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0354-10.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0354-10.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0354-11.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0354-11.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0354-12.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0354-12.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0355-01.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0355-01.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0355-02.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0355-02.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0355-03.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0355-03.nc'},
#  {'s3_path': 's3://us-west-2.opendata.source.coop/cworthy/oae-efficiency-atlas/data/experiments/005/01/alk-forcing.005-1999-01.pop.h.0355-04.nc',
#   'cache_path': '/pscratch/sd/m/mattlong/atlas_cache/experiments/005/01/alk-forcing.005-1999-01.pop.h.0355-04.nc'},
#  ...]

# %% [markdown]
# ## Step 2: Download missing files in batches
#
# Downloads happen in batches to reduce overhead and better utilize S3 transfer throughput.

# %%
downloaded = atlas_data.ensure_cache(polygon_id=polygon_id, injection_year=injection_year, injection_month=injection_month, n_test=n_test)

print(f"Downloaded {downloaded} file(s) to cache: {cdr_atlas.CACHE_DIR}")

# %% [markdown]
# ## Step 3: Open cached data and inspect variables
#
# This uses the cached NetCDF files and avoids any further network transfer.

# %%
ds = atlas_data.open_dataset(polygon_id=polygon_id, injection_year=injection_year, injection_month=injection_month, n_test=n_test)
ds

# %% [markdown]
# ## Plot 1: Polygon mask overview
#
# The polygon masks dataset defines the spatial regions used in the experiments. This plot previews the polygon IDs on the global grid.

# %%
ds_atlas_polygons = atlas_data.get_polygon_masks_dataset()
polygon_ids = ds_atlas_polygons.polygon_id
polygon_ids.plot()

# %% [markdown]
# ## Plot 2: Example FG_CO2 slice
#
# The dataset includes FG_CO2 and FG_ALT_CO2 variables (perturbation vs. counterfactual). This plots one slice for the selected polygon and injection date.

# %%
injection_date = f"{injection_year:04d}-{injection_month:02d}"

fg_co2 = ds.FG_CO2.sel(
    polygon_id=polygon_id, injection_date=injection_date
).isel(elapsed_time=0)

fg_co2.plot()

# %% [markdown]
# ## Example 3: Subset to a ROMS-Tools grid
#
# Use a ROMS-Tools grid YAML to find which atlas polygons intersect your model domain. This is a lightweight spatial filter that you can use before downloading or integrating data.

# %%
from parsers import load_roms_tools_object
domain_name = "cson_roms-marbl_v0.1_ccs-12km"

# Path to a ROMS-Tools grid YAML
grid_yaml = f"cson_forge/blueprints/{domain_name}/_grid.yml"
model_grid = load_roms_tools_object(grid_yaml)

model_grid.plot()

# %%
# Create AtlasModelGridAnalyzer instance
analyzer = cdr_atlas.AtlasModelGridAnalyzer(model_grid, atlas_data)

# Get polygon IDs within model grid boundaries
print(f"Found {len(analyzer.polygon_ids_in_bounds)} unique polygon IDs within model grid boundaries")
print(f"Polygon IDs: {analyzer.polygon_ids_in_bounds[:100]}..." if len(analyzer.polygon_ids_in_bounds) > 100 else f"Polygon IDs: {analyzer.polygon_ids_in_bounds}")

analyzer.polygon_id_mask.plot(vmin=-1, vmax=analyzer.polygon_id_mask.max())

# %% [markdown]
# ## Notes and references
#
# - Data source and full README: https://source.coop/cworthy/oae-efficiency-atlas
# - Cached files are stored under `cdr_atlas.CACHE_DIR` (defaults to `$SCRATCH/atlas_cache`).
